# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.image as mpimg
sns.set(style="darkgrid")

# %%
df = pd.read_csv("NYPD_Complaint_Data_Historic.tsv", sep="\t")

# %%
sns.set(style="white")
map_img=mpimg.imread('New-York-City-boundary-map2.png')
g = sns.jointplot(x=df['X_COORD_CD'].values, y=df['Y_COORD_CD'].values, height=10, kind='hex', alpha=0.8, color="r")
g.ax_joint.imshow(map_img, aspect = 'equal',extent = g.ax_joint.get_xlim() + g.ax_joint.get_ylim(),zorder = 1, alpha=0.2, origin='upper')
g.set_axis_labels('X Coordinate', 'Y Coordinate', fontsize=20)
plt.tight_layout()
plt.show()

# %%
sns.set(style="white")
map_img=mpimg.imread('New-York-City-boundary-map2.png')
g = sns.jointplot(x=df['X_COORD_CD'].values, y=df['Y_COORD_CD'].values, height=10, kind='hex', alpha=0.8, color="r")
g.ax_joint.imshow(map_img, aspect = 'equal',extent = g.ax_joint.get_xlim() + g.ax_joint.get_ylim(),zorder = 1, alpha=0.2, origin='upper')
plt.ylabel('Longitude', fontsize=12)
plt.xlabel('Latitude', fontsize=12)
plt.show()
